# %% [markdown]
# # Find the Best Location for Restaurant Near Contrad Hotel

# %% [markdown]
# ### In this project, I am going to select the best location for the restaurant near the University of Rochester. Therefore I will need the dataset of the restaurant venues near the university. After that, I will spot the location of current restaurant and visualize them on the map using the folium.

# %% [markdown]
# ## This project can help the enterprise to find the best location for their restaurant in the future.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-83932640fd51> in <module>
#      13 from pandas.io.json import json_normalize
#      14
# ---> 15 import folium # plotting library
#      16
#      17 print('Folium installed')
#
# ModuleNotFoundError: No module named 'folium'

# %%
CLIENT_ID = 'C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S' # your Foursquare ID
CLIENT_SECRET = 'QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS' # your Foursquare Secret
VERSION = '20200704'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S
# CLIENT_SECRET:QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS

# %%
address = 'Elmwood Ave, Rochester, NY'
#'102 North End Ave, New York, NY'#
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.125455 -77.597612

# %%
search_query = 'restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S&client_secret=QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS&ll=43.125455,-77.597612&v=20200704&query=restaurant&radius=50000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f048c6936812b11762676ea'},
#  'response': {'venues': [{'id': '4babc69ff964a52098c83ae3',
#     'name': 'Golden Dynasty Chinese Restaurant',
#     'location': {'address': '1900 Clinton Ave S',
#      'lat': 43.120570772374364,
#      'lng': -77.59329450163801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.120570772374364,
#        'lng': -77.59329450163801},
#       {'label': 'entrance', 'lat': 43.121319, 'lng': -77.59426}],
#      'distance': 647,
#      'postalCode': '14618',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1900 Clinton Ave S',
#       'Rochester, NY 14618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4bd77c760b779c74a75605a0',
#     'name': 'Lilu Cafe & Ethiopian Restaurant',
#     'location': {'address': '1009 Clinton Ave S',
#      'lat': 43.13836669921875,
#      'lng': -77.59530639648438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.13836669921875,
#        'lng': -77.59530639648438}],
#      'distance': 1449,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1009 Clinton Ave S',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10a941735',
#       'name': 'Ethiopian Restaurant',
#       'pluralName': 'Ethiopian Restaurants',
#       'shortName': 'Ethiopian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ethiopian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '501d4fb2e4b0cf97af8c62ef',
#     'name': 'The Restaurant At The Armory (TRATA)',
#     'location': {'address': '145 Culver Rd',
#      'lat': 43.14223,
#      'lng': -77.57666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14223,
#        'lng': -77.57666}],
#      'distance': 2526,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['145 Culver Rd',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48369080'},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5bb7cd73a35f460025d0173f',
#     'name': 'Peppapot Jamaican Restaurant and Catering',
#     'location': {'address': '133 Gregory St',
#      'crossStreet': 'Ashland St',
#      'lat': 43.14182964095191,
#      'lng': -77.60880321264267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14182964095191,
#        'lng': -77.60880321264267},
#       {'label': 'entrance', 'lat': 43.141782, 'lng': -77.608879}],
#      'distance': 2036,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['133 Gregory St (Ashland St)',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4bdf4a66e75c0f472897ca03',
#     'name': 'SEA Restaurant',
#     'location': {'address': '741 Monroe Ave',
#      'crossStreet': 'Rutgers St',
#      'lat': 43.143280316606905,
#      'lng': -77.58807427466596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.143280316606905,
#        'lng': -77.58807427466596}],
#      'distance': 2130,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['741 Monroe Ave (Rutgers St)',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '554f6797498ece2b655eb427',
#     'name': "Joey B's Restaurant",
#     'location': {'address': '1325 Elmwood Ave',
#      'crossStreet': 'Lilac Dr.',
#      'lat': 43.12335968017578,
#      'lng': -77.60345458984375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.12335968017578,
#        'lng': -77.60345458984375}],
#      'distance': 528,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1325 Elmwood Ave (Lilac Dr.)',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1500631',
#      'url': 'https://www.grubhub.com/restaurant/joey-bs-1325-elmwood-ave-rochester/1500631?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1500631',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '53ebd1fd498e6ee1435862dc',
#     'name': 'Restaurant Depot',
#     'location': {'address': '80 Ridgeland Road',
#      'lat': 43.091910999999996,
#      'lng': -77.600555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.091910999999996,
#        'lng': -77.600555}],
#      'distance': 3741,
#      'postalCode': '14623',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80 Ridgeland Road',
#       'Rochester, NY 14623',
#       'United States']},
#     'categories': [{'id': '52e816a6bcbc57f1066b7a54',
#       'name': 'Warehouse Store',
#       'pluralName': 'Warehouse Stores',
#       'shortName': 'Warehouse Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '518e68d7498ef0d390d3128b',
#     'name': 'Amore Italian Restaurant & Wine Bar by Wegmans',
#     'location': {'address': '1750 East Ave',
#      'lat': 43.14593922729457,
#      'lng': -77.55665020361809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14593922729457,
#        'lng': -77.55665020361809},
#       {'label': 'entrance', 'lat': 43.145875, 'lng': -77.556641}],
#      'distance': 4033,
#      'postalCode': '14610',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1750 East Ave',
#       'Rochester, NY 14610',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4c0581a7191f20a1f22fe314',
#     'name': 'Dac Hoa Restaurant',
#     'location': {'address': '230 Monroe Ave',
#      'lat': 43.15001250635744,
#      'lng': -77.59947105448137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.15001250635744,
#        'lng': -77.59947105448137},
#       {'label': 'entrance', 'lat': 43.150029, 'lng': -77.599575}],
#      'distance': 2737,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['230 Monroe Ave',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1330140',
#      'url': 'https://www.grubhub.com/restaurant/dac-hoa-230-monroe-avenue-rochester/1330140?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1330140',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b85bed7f964a520997031e3',
#     'name': 'Chopsticks Chinese Restaurant',
#     'location': {'address': '125 White Spruce Blvd',
#      'lat': 43.10541676249526,
#      'lng': -77.61786840110658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.10541676249526,
#        'lng': -77.61786840110658}],
#      'distance': 2772,
#      'postalCode': '14623',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['125 White Spruce Blvd',
#       'Rochester, NY 14623',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1330992',
#      'url': 'https://www.grubhub.com/restaurant/chopsticks-chinese-restaurant-125-white-spruce-boulevard-rochester/1330992?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1330992',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4e4e47e4bd4101d0d7a6bb5e',
#     'name': 'Rong Cheng Chinese Restaurant',
#     'location': {'address': '17 Richmond St',
#      'lat': 43.158662,
#      'lng': -77.597982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.158662,
#        'lng': -77.597982},
#       {'label': 'entrance', 'lat': 43.15883, 'lng': -77.597939}],
#      'distance': 3696,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['17 Richmond St',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '504140e8e4b00fd08e8d0511',
#     'name': "LJ's Take Out & Restaurant 2",
#     'location': {'address': '38 Saint Paul St',
#      'lat': 43.15747833251953,
#      'lng': -77.609130859375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.15747833251953,
#        'lng': -77.609130859375}],
#      'distance': 3685,
#      'postalCode': '14604',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['38 Saint Paul St',
#       'Rochester, NY 14604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b9962e9f964a520967735e3',
#     'name': 'Youngs Korean Restaurant',
#     'location': {'address': '120 Mushroom Blvd',
#      'lat': 43.09114583751294,
#      'lng': -77.6190128798253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.09114583751294,
#        'lng': -77.6190128798253},
#       {'label': 'entrance', 'lat': 43.091048, 'lng': -77.618977}],
#      'distance': 4196,
#      'postalCode': '14623',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Mushroom Blvd',
#       'Rochester, NY 14623',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1331767',
#      'url': 'https://www.grubhub.com/restaurant/youngs-korean-restaurant-120-mushroom-boulevard-rochester/1331767?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1331767',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4aafc2cdf964a520a46420e3',
#     'name': "Spiro's Family Restaurant",
#     'location': {'address': '490 State St',
#      'lat': 43.1638,
#      'lng': -77.62182800000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.1638,
#        'lng': -77.62182800000001},
#       {'label': 'entrance', 'lat': 43.163764, 'lng': -77.62191}],
#      'distance': 4699,
#      'postalCode': '14608',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['490 State St',
#       'Rochester, NY 14608',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1506068',
#      'url': 'https://www.grubhub.com/restaurant/spiros-restaurant-490-state-street-rochester/1506068?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1506068',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b61ae35f964a520f41c2ae3',
#     'name': "Salena's Mexican Restaurant",
#     'location': {'address': '302 Goodman St N',
#      'crossStreet': 'at Village Gate Square',
#      'lat': 43.15900023987086,
#      'lng': -77.58491483722032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.15900023987086,
#        'lng': -77.58491483722032}],
#      'distance': 3874,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['302 Goodman St N (at Village Gate Square)',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b6c99d0f964a520c0452ce3',
#     'name': 'Seoul House Restaurant',
#     'location': {'address': '2805 W Henrietta Rd',
#      'lat': 43.09567802702606,
#      'lng': -77.63264351448068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.09567802702606,
#        'lng': -77.63264351448068}],
#      'distance': 4369,
#      'postalCode': '14623',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2805 W Henrietta Rd',
#       'Rochester, NY 14623',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '559c0b82498ed13231e6bea8',
#     'name': 'Restaurant Fiorella',
#     'location': {'address': '5 Public Market',
#      'crossStreet': 'South Union Street',
#      'lat': 43.16582198528039,
#      'lng': -77.59004883724495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.16582198528039,
#        'lng': -77.59004883724495}],
#      'distance': 4535,
#      'postalCode': '14609',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Public Market (South Union Street)',
#       'Rochester, NY 14609',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4d3ba5e2557d6dcb63f53244',
#     'name': "LJ's Take Out & Restaurant",
#     'location': {'address': '360 Thurston Rd',
#      'lat': 43.137796,
#      'lng': -77.650707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.137796,
#        'lng': -77.650707},
#       {'label': 'entrance', 'lat': 43.137795, 'lng': -77.650835}],
#      'distance': 4526,
#      'postalCode': '14619',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['360 Thurston Rd',
#       'Rochester, NY 14619',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5ba6920c898bdc002b147887',
#     'name': 'Akwaaba Restaurant',
#     'location': {'lat': 43.123978,
#      'lng': -77.6176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.123978,
#        'lng': -77.6176}],
#      'distance': 1632,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Rochester, NY 14620', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c8941735',
#       'name': 'African Restaurant',
#       'pluralName': 'African Restaurants',
#       'shortName': 'African',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '51f3094b498e3da43eb93dc2',
#     'name': 'Zemeta Ethiopian Restaurant',
#     'location': {'address': '1015 Clinton Ave S',
#      'lat': 43.138553785927414,
#      'lng': -77.59524063326188,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.138553785927414,
#        'lng': -77.59524063326188}],
#      'distance': 1470,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1015 Clinton Ave S',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10a941735',
#       'name': 'Ethiopian Restaurant',
#       'pluralName': 'Ethiopian Restaurants',
#       'shortName': 'Ethiopian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ethiopian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1432542',
#      'url': 'https://www.grubhub.com/restaurant/zemeta-ethiopian-restaurant-1015-s-clinton-ave-rochester/1432542?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1432542',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b643be6f964a52089a52ae3',
#     'name': 'Peppermill Restaurant',
#     'location': {'address': '1776 Dewey Ave',
#      'lat': 43.19997668709689,
#      'lng': -77.63854007143645,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.19997668709689,
#        'lng': -77.63854007143645}],
#      'distance': 8936,
#      'postalCode': '14615',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1776 Dewey Ave',
#       'Rochester, NY 14615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1330465',
#      'url': 'https://www.grubhub.com/restaurant/peppermill-restaurant-1776-dewey-avenue-rochester/1330465?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1330465',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4f32622e19836c91c7d2744b',
#     'name': "Skippy's Vegeterian Restaurant",
#     'location': {'address': '742 South Ave',
#      'lat': 43.140710999999996,
#      'lng': -77.604664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.140710999999996,
#        'lng': -77.604664}],
#      'distance': 1792,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['742 South Ave',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b8c4fc3f964a520efc932e3',
#     'name': "Timothy Patrick's Irish Restaurant",
#     'location': {'address': '916 Panorama Trl S',
#      'lat': 43.12601755030661,
#      'lng': -77.4908685871614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.12601755030661,
#        'lng': -77.4908685871614}],
#      'distance': 8672,
#      'postalCode': '14625',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['916 Panorama Trl S',
#       'Rochester, NY 14625',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4e8473d9b8f7a99150a0d208',
#     'name': 'Reflections Restaurant',
#     'location': {'lat': 43.10173225582329,
#      'lng': -77.60911992634111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.10173225582329,
#        'lng': -77.60911992634111}],
#      'distance': 2801,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4f321ee219836c91c7b80371',
#     'name': 'Savory Thyme Restaurant',
#     'location': {'address': '21 Shepard St',
#      'lat': 43.140128999999995,
#      'lng': -77.583647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.140128999999995,
#        'lng': -77.583647},
#       {'label': 'entrance', 'lat': 43.140096, 'lng': -77.583534}],
#      'distance': 1988,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['21 Shepard St',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b4a8dc2f964a5207f8a26e3',
#     'name': 'India House Restaurant',
#     'location': {'address': '998 Clinton Ave S',
#      'lat': 43.13888223273507,
#      'lng': -77.59513065790021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.13888223273507,
#        'lng': -77.59513065790021},
#       {'label': 'entrance', 'lat': 43.13885, 'lng': -77.595185}],
#      'distance': 1508,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['998 Clinton Ave S',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '338147',
#      'url': 'https://www.grubhub.com/restaurant/india-house-restaurant-rochester-998-clinton-ave-s-rochester/338147?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=338147',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '58513363'},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4ace2e17f964a520dfce20e3',
#     'name': 'Jines Restaurant',
#     'location': {'address': '658 Park Ave',
#      'crossStreet': 'Berkeley St',
#      'lat': 43.1482724,
#      'lng': -77.57797839999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.1482724,
#        'lng': -77.57797839999999},
#       {'label': 'entrance', 'lat': 43.148269, 'lng': -77.578053}],
#      'distance': 2999,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['658 Park Ave (Berkeley St)',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2191942',
#      'url': 'https://www.grubhub.com/restaurant/jines-restaurant-658-park-ave-rochester/2191942?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2191942',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '94914934'},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4e3f010de4cdab9b93587099',
#     'name': 'Wang Chinese Restaurant',
#     'location': {'address': '1415 N Clinton Ave',
#      'lat': 43.185668,
#      'lng': -77.6151,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.185668,
#        'lng': -77.6151}],
#      'distance': 6851,
#      'postalCode': '14621',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1415 N Clinton Ave',
#       'Rochester, NY 14621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '581504ccd67c3973889bf23f',
#     'name': 'Cedar Lebanese Restaurant',
#     'location': {'address': '746 Monroe Ave',
#      'lat': 43.14330862108667,
#      'lng': -77.58799779119677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14330862108667,
#        'lng': -77.58799779119677}],
#      'distance': 2135,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['746 Monroe Ave',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4bc31e264cdfc9b699dc9621',
#     'name': "Tom's Restaurant",
#     'location': {'address': '740 E Ridge Rd',
#      'lat': 43.197015185494166,
#      'lng': -77.59939427542203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.197015185494166,
#        'lng': -77.59939427542203}],
#      'distance': 7967,
#      'postalCode': '14621',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['740 E Ridge Rd',
#       'Rochester, NY 14621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1504603',
#      'url': 'https://www.grubhub.com/restaurant/toms-restaurant-740-east-ridge-road-rochester/1504603?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1504603',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5776b41a498e9b4c2d48fb3d',
#     'name': 'Reggae Jamaica Restaurant & Bakery',
#     'location': {'address': '1485 Dewey Ave',
#      'lat': 43.1940479,
#      'lng': -77.63917510000002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.1940479,
#        'lng': -77.63917510000002}],
#      'distance': 8348,
#      'postalCode': '14615',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1485 Dewey Ave',
#       'Rochester, NY 14615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '209594127'},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '583e323e9b615c0be1466522',
#     'name': 'Cedar Restaurant',
#     'location': {'address': '746 Monroe Ave',
#      'crossStreet': 'Rutgers St',
#      'lat': 43.1435244741491,
#      'lng': -77.58781626820564,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.1435244741491,
#        'lng': -77.58781626820564}],
#      'distance': 2163,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['746 Monroe Ave (Rutgers St)',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4bdd9738aebd2d7f6663af51',
#     'name': 'Lehigh Restaurant',
#     'location': {'address': '4835 W Henrietta Rd',
#      'lat': 43.05699751101155,
#      'lng': -77.65400794909723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.05699751101155,
#        'lng': -77.65400794909723}],
#      'distance': 8893,
#      'postalCode': '14467',
#      'cc': 'US',
#      'city': 'Henrietta',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4835 W Henrietta Rd',
#       'Henrietta, NY 14467',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4be930afd837c9b67a1ba606',
#     'name': "Uncle Danny's Restaurant",
#     'location': {'address': '555 E Ridge Rd',
#      'lat': 43.19526099248838,
#      'lng': -77.60352255593259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.19526099248838,
#        'lng': -77.60352255593259}],
#      'distance': 7785,
#      'postalCode': '14621',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['555 E Ridge Rd',
#       'Rochester, NY 14621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1503220',
#      'url': 'https://www.grubhub.com/restaurant/uncle-dannys-family-restaurant-555-east-ridge-road-rochester/1503220?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1503220',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4bb4cfefa70595216fb91bce',
#     'name': "Rooney's Restaurant",
#     'location': {'address': '90 Henrietta St',
#      'crossStreet': 'Monroe Ave',
#      'lat': 43.14060087993469,
#      'lng': -77.59324051632896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14060087993469,
#        'lng': -77.59324051632896},
#       {'label': 'entrance', 'lat': 43.140024, 'lng': -77.593177}],
#      'distance': 1723,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['90 Henrietta St (Monroe Ave)',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1507595',
#      'url': 'https://www.grubhub.com/restaurant/rooneys-90-henrietta-street-rochester/1507595?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1507595',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4f32b3d319836c91c7f15ce9',
#     'name': 'Dashen Restaurant',
#     'location': {'address': '503 South Ave',
#      'lat': 43.145877838134766,
#      'lng': -77.60570526123047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.145877838134766,
#        'lng': -77.60570526123047}],
#      'distance': 2366,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['503 South Ave',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4c5db9ae857ca5938dbbcdcb',
#     'name': 'Kessler Restaurant Support Center',
#     'location': {'address': '410 White Spruce Blvd',
#      'lat': 43.10295083333333,
#      'lng': -77.61815981666666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.10295083333333,
#        'lng': -77.61815981666666}],
#      'distance': 3010,
#      'postalCode': '14623',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['410 White Spruce Blvd',
#       'Rochester, NY 14623',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4c66e1328e9120a1482dd964',
#     'name': 'King Food Chinese Restaurant',
#     'location': {'address': '1384 Norton St',
#      'lat': 43.187911,
#      'lng': -77.585202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.187911,
#        'lng': -77.585202},
#       {'label': 'entrance', 'lat': 43.187801, 'lng': -77.585078}],
#      'distance': 7025,
#      'postalCode': '14621',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1384 Norton St',
#       'Rochester, NY 14621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4ce7613ff1c6236a917859f0',
#     'name': 'Cactus Restaurant & Bar',
#     'location': {'address': '1360 Dewey Ave',
#      'lat': 43.191383361816406,
#      'lng': -77.63858032226562,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 43.191407,
#        'lng': -77.638621},
#       {'label': 'display',
#        'lat': 43.191383361816406,
#        'lng': -77.63858032226562}],
#      'distance': 8057,
#      'postalCode': '14613',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1360 Dewey Ave',
#       'Rochester, NY 14613',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5b129d67974617002c0447f2',
#     'name': "Kamara's West African Restaurant",
#     'location': {'address': '777 Plymouth Ave',
#      'crossStreet': 'Violetta St',
#      'lat': 43.14089217839027,
#      'lng': -77.6214612275362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14089217839027,
#        'lng': -77.6214612275362}],
#      'distance': 2589,
#      'postalCode': '14608',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['777 Plymouth Ave (Violetta St)',
#       'Rochester, NY 14608',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c8941735',
#       'name': 'African Restaurant',
#       'pluralName': 'African Restaurants',
#       'shortName': 'African',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '844083',
#      'url': 'https://www.grubhub.com/restaurant/kamaras-african-restaurant-777-plymouth-ave-s-rochester/844083?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=844083',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5ccd3303446ea6002c46eef4',
#     'name': 'Kamara’s African Restaurant',
#     'location': {'address': '777 S Plymouth Ave',
#      'lat': 43.1409612,
#      'lng': -77.6214042,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.1409612,
#        'lng': -77.6214042}],
#      'distance': 2591,
#      'postalCode': '14608',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['777 S Plymouth Ave',
#       'Rochester, NY 14608',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '538890584'},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '50746a68e4b0531e5c6324a7',
#     'name': 'Alley Cat Restaurant',
#     'location': {'lat': 43.149205,
#      'lng': -77.589111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.149205,
#        'lng': -77.589111}],
#      'distance': 2732,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Rochester, NY 14607', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f7941735',
#       'name': 'Flea Market',
#       'pluralName': 'Flea Markets',
#       'shortName': 'Flea Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '521bd78e498e0a529505bdc8',
#     'name': 'SEA Restaurant',
#     'location': {'address': '1675 Mount Hope Ave',
#      'lat': 43.11731403610523,
#      'lng': -77.62140743313451,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.11731403610523,
#        'lng': -77.62140743313451},
#       {'label': 'entrance', 'lat': 43.117494, 'lng': -77.621755}],
#      'distance': 2135,
#      'postalCode': '14620',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1675 Mount Hope Ave',
#       'Rochester, NY 14620',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '58b9cec00aac755b158af2f5',
#     'name': 'Dalia’s Mediterranean Restaurant',
#     'location': {'address': '1220 Fairport Rd',
#      'lat': 43.102745,
#      'lng': -77.465935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.102745,
#        'lng': -77.465935}],
#      'distance': 10994,
#      'postalCode': '14450',
#      'cc': 'US',
#      'city': 'Fairport',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1220 Fairport Rd',
#       'Fairport, NY 14450',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '313817',
#      'url': 'https://www.grubhub.com/restaurant/dalias-mediterranean-restaurant-1220-fairport-rd-fairport/313817?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=313817',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '5004c270e4b0004dbf991fb9',
#     'name': 'Asian Jade Restaurant',
#     'location': {'address': '1780 E Ridge Rd',
#      'lat': 43.20172882080078,
#      'lng': -77.57008361816406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.20172882080078,
#        'lng': -77.57008361816406}],
#      'distance': 8779,
#      'postalCode': '14622',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1780 E Ridge Rd',
#       'Rochester, NY 14622',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4b47dfdff964a5206a4226e3',
#     'name': "Charlie's Restaurant",
#     'location': {'address': '1843 Empire Blvd',
#      'crossStreet': 'btwn Bay & Smith Rd',
#      'lat': 43.18850206072805,
#      'lng': -77.50537409649661,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.18850206072805,
#        'lng': -77.50537409649661}],
#      'distance': 10264,
#      'postalCode': '14580',
#      'cc': 'US',
#      'city': 'Webster',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1843 Empire Blvd (btwn Bay & Smith Rd)',
#       'Webster, NY 14580',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4ba16b08f964a52036b537e3',
#     'name': "Pixley's Restaurant",
#     'location': {'address': '2235 Buffalo Rd',
#      'lat': 43.146797366954715,
#      'lng': -77.71058912856603,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.146797366954715,
#        'lng': -77.71058912856603}],
#      'distance': 9479,
#      'postalCode': '14624',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2235 Buffalo Rd',
#       'Rochester, NY 14624',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1331740',
#      'url': 'https://www.grubhub.com/restaurant/pixleys-restaurant-2235-buffalo-road-rochester/1331740?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1331740',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4f32561319836c91c7cdb750',
#     'name': 'Sapore Restaurant',
#     'location': {'address': '262 Park Ave',
#      'lat': 43.150508880615234,
#      'lng': -77.5887680053711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.150508880615234,
#        'lng': -77.5887680053711}],
#      'distance': 2880,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['262 Park Ave',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4f44a68719836ed001958e62',
#     'name': 'Number One Rochester Restaurant',
#     'location': {'address': '2317 Buffalo Rd',
#      'lat': 43.14513397216797,
#      'lng': -77.71141052246094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.14513397216797,
#        'lng': -77.71141052246094}],
#      'distance': 9500,
#      'postalCode': '14624',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2317 Buffalo Rd',
#       'Rochester, NY 14624',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False},
#    {'id': '4e4c846cbd413c4cc669f747',
#     'name': 'Kobay Japanese Restaurant',
#     'location': {'address': '690 Park Ave',
#      'lat': 43.147961,
#      'lng': -77.577236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.147961,
#        'lng': -77.577236}],
#      'distance': 3002,
#      'postalCode': '14607',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['690 Park Ave',
#       'Rochester, NY 14607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594133382',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...         NaN
# 1  [{'id': '4bf58dd8d48988d10a941735', 'name': 'E...         NaN
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...         NaN
# 3  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id    location.address  ... location.distance  \
# 0  4babc69ff964a52098c83ae3  1900 Clinton Ave S  ...               647
# 1  4bd77c760b779c74a75605a0  1009 Clinton Ave S  ...              1449
# 2  501d4fb2e4b0cf97af8c62ef       145 Culver Rd  ...              2526
# 3  5bb7cd73a35f460025d0173f      133 Gregory St  ...              2036
# 4  4bdf4a66e75c0f472897ca03      741 Monroe Ave  ...              2130
#
#                            location.formattedAddress  \
# 0  [1900 Clinton Ave S, Rochester, NY 14618, Unit...
# 1  [1009 Clinton Ave S, Rochester, NY 14620, Unit...
# 2  [145 Culver Rd, Rochester, NY 14620, United St...
# 3  [133 Gregory St (Ashland St), Rochester, NY 14...
# 4  [741 Monroe Ave (Rutgers St), Rochester, NY 14...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 43.12057077237436...    43.120571
# 1  [{'label': 'display', 'lat': 43.13836669921875...    43.138367
# 2  [{'label': 'display', 'lat': 43.14223, 'lng': ...    43.142230
# 3  [{'label': 'display', 'lat': 43.14182964095191...    43.141830
# 4  [{'label': 'display', 'lat': 43.14328031660690...    43.143280
#
#    location.lng location.postalCode location.state  \
# 0    -77.593295               14618             NY
# 1    -77.595306               14620             NY
# 2    -77.576660               14620             NY
# 3    -77.608803               14620             NY
# 4    -77.588074               14607             NY
#
#                                         name    referralId venuePage.id
# 0          Golden Dynasty Chinese Restaurant  v-1594133382          NaN
# 1           Lilu Cafe & Ethiopian Restaurant  v-1594133382          NaN
# 2       The Restaurant At The Armory (TRATA)  v-1594133382     48369080
# 3  Peppapot Jamaican Restaurant and Catering  v-1594133382          NaN
# 4                             SEA Restaurant  v-1594133382          NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                               name                 categories  \
# 0                Golden Dynasty Chinese Restaurant         Chinese Restaurant
# 1                 Lilu Cafe & Ethiopian Restaurant       Ethiopian Restaurant
# 2             The Restaurant At The Armory (TRATA)        American Restaurant
# 3        Peppapot Jamaican Restaurant and Catering       Caribbean Restaurant
# 4                                   SEA Restaurant      Vietnamese Restaurant
# 5                              Joey B's Restaurant                 Steakhouse
# 6                                 Restaurant Depot            Warehouse Store
# 7   Amore Italian Restaurant & Wine Bar by Wegmans                 Restaurant
# 8                               Dac Hoa Restaurant      Vietnamese Restaurant
# 9                    Chopsticks Chinese Restaurant         Chinese Restaurant
# 10                   Rong Cheng Chinese Restaurant         Chinese Restaurant
# 11                    LJ's Take Out & Restaurant 2       Caribbean Restaurant
# 12                        Youngs Korean Restaurant          Korean Restaurant
# 13                       Spiro's Family Restaurant                      Diner
# 14                     Salena's Mexican Restaurant         Mexican Restaurant
# 15                          Seoul House Restaurant          Korean Restaurant
# 16                             Restaurant Fiorella                 Restaurant
# 17                      LJ's Take Out & Restaurant       Caribbean Restaurant
# 18                              Akwaaba Restaurant         African Restaurant
# 19                     Zemeta Ethiopian Restaurant       Ethiopian Restaurant
# 20                           Peppermill Restaurant        American Restaurant
# 21                  Skippy's Vegeterian Restaurant                       Food
# 22              Timothy Patrick's Irish Restaurant                        Pub
# 23                          Reflections Restaurant        American Restaurant
# 24                         Savory Thyme Restaurant                       Food
# 25                          India House Restaurant          Indian Restaurant
# 26                                Jines Restaurant             Breakfast Spot
# 27                         Wang Chinese Restaurant         Chinese Restaurant
# 28                       Cedar Lebanese Restaurant  Middle Eastern Restaurant
# 29                                Tom's Restaurant                      Diner
# 30              Reggae Jamaica Restaurant & Bakery                 Food Court
# 31                                Cedar Restaurant  Middle Eastern Restaurant
# 32                               Lehigh Restaurant                      Diner
# 33                        Uncle Danny's Restaurant                      Diner
# 34                             Rooney's Restaurant        American Restaurant
# 35                               Dashen Restaurant                       Food
# 36               Kessler Restaurant Support Center                     Office
# 37                    King Food Chinese Restaurant         Chinese Restaurant
# 38                         Cactus Restaurant & Bar        American Restaurant
# 39                Kamara's West African Restaurant         African Restaurant
# 40                     Kamara’s African Restaurant                 Food Court
# 41                            Alley Cat Restaurant                Flea Market
# 42                                  SEA Restaurant      Vietnamese Restaurant
# 43                Dalia’s Mediterranean Restaurant   Mediterranean Restaurant
# 44                           Asian Jade Restaurant           Asian Restaurant
# 45                            Charlie's Restaurant               Burger Joint
# 46                             Pixley's Restaurant                      Diner
# 47                               Sapore Restaurant                       Food
# 48                 Number One Rochester Restaurant         Chinese Restaurant
# 49                       Kobay Japanese Restaurant        Japanese Restaurant
#
#                   address  cc       city        country  \
# 0      1900 Clinton Ave S  US  Rochester  United States
# 1      1009 Clinton Ave S  US  Rochester  United States
# 2           145 Culver Rd  US  Rochester  United States
# 3          133 Gregory St  US  Rochester  United States
# 4          741 Monroe Ave  US  Rochester  United States
# 5        1325 Elmwood Ave  US  Rochester  United States
# 6       80 Ridgeland Road  US  Rochester  United States
# 7           1750 East Ave  US  Rochester  United States
# 8          230 Monroe Ave  US  Rochester  United States
# 9   125 White Spruce Blvd  US  Rochester  United States
# 10         17 Richmond St  US  Rochester  United States
# 11       38 Saint Paul St  US  Rochester  United States
# 12      120 Mushroom Blvd  US  Rochester  United States
# 13           490 State St  US  Rochester  United States
# 14       302 Goodman St N  US  Rochester  United States
# 15    2805 W Henrietta Rd  US  Rochester  United States
# 16        5 Public Market  US  Rochester  United States
# 17        360 Thurston Rd  US  Rochester  United States
# 18                    NaN  US  Rochester  United States
# 19     1015 Clinton Ave S  US  Rochester  United States
# 20         1776 Dewey Ave  US  Rochester  United States
# 21          742 South Ave  US  Rochester  United States
# 22     916 Panorama Trl S  US  Rochester  United States
# 23                    NaN  US        NaN  United States
# 24          21 Shepard St  US  Rochester  United States
# 25      998 Clinton Ave S  US  Rochester  United States
# 26           658 Park Ave  US  Rochester  United States
# 27     1415 N Clinton Ave  US  Rochester  United States
# 28         746 Monroe Ave  US  Rochester  United States
# 29         740 E Ridge Rd  US  Rochester  United States
# 30         1485 Dewey Ave  US  Rochester  United States
# 31         746 Monroe Ave  US  Rochester  United States
# 32    4835 W Henrietta Rd  US  Henrietta  United States
# 33         555 E Ridge Rd  US  Rochester  United States
# 34        90 Henrietta St  US  Rochester  United States
# 35          503 South Ave  US  Rochester  United States
# 36  410 White Spruce Blvd  US  Rochester  United States
# 37         1384 Norton St  US  Rochester  United States
# 38         1360 Dewey Ave  US  Rochester  United States
# 39       777 Plymouth Ave  US  Rochester  United States
# 40     777 S Plymouth Ave  US  Rochester  United States
# 41                    NaN  US  Rochester  United States
# 42    1675 Mount Hope Ave  US  Rochester  United States
# 43       1220 Fairport Rd  US   Fairport  United States
# 44        1780 E Ridge Rd  US  Rochester  United States
# 45       1843 Empire Blvd  US    Webster  United States
# 46        2235 Buffalo Rd  US  Rochester  United States
# 47           262 Park Ave  US  Rochester  United States
# 48        2317 Buffalo Rd  US  Rochester  United States
# 49           690 Park Ave  US  Rochester  United States
#
#                crossStreet  distance  \
# 0                      NaN       647
# 1                      NaN      1449
# 2                      NaN      2526
# 3               Ashland St      2036
# 4               Rutgers St      2130
# 5                Lilac Dr.       528
# 6                      NaN      3741
# 7                      NaN      4033
# 8                      NaN      2737
# 9                      NaN      2772
# 10                     NaN      3696
# 11                     NaN      3685
# 12                     NaN      4196
# 13                     NaN      4699
# 14  at Village Gate Square      3874
# 15                     NaN      4369
# 16      South Union Street      4535
# 17                     NaN      4526
# 18                     NaN      1632
# 19                     NaN      1470
# 20                     NaN      8936
# 21                     NaN      1792
# 22                     NaN      8672
# 23                     NaN      2801
# 24                     NaN      1988
# 25                     NaN      1508
# 26             Berkeley St      2999
# 27                     NaN      6851
# 28                     NaN      2135
# 29                     NaN      7967
# 30                     NaN      8348
# 31              Rutgers St      2163
# 32                     NaN      8893
# 33                     NaN      7785
# 34              Monroe Ave      1723
# 35                     NaN      2366
# 36                     NaN      3010
# 37                     NaN      7025
# 38                     NaN      8057
# 39             Violetta St      2589
# 40                     NaN      2591
# 41                     NaN      2732
# 42                     NaN      2135
# 43                     NaN     10994
# 44                     NaN      8779
# 45     btwn Bay & Smith Rd     10264
# 46                     NaN      9479
# 47                     NaN      2880
# 48                     NaN      9500
# 49                     NaN      3002
#
#                                      formattedAddress  \
# 0   [1900 Clinton Ave S, Rochester, NY 14618, Unit...
# 1   [1009 Clinton Ave S, Rochester, NY 14620, Unit...
# 2   [145 Culver Rd, Rochester, NY 14620, United St...
# 3   [133 Gregory St (Ashland St), Rochester, NY 14...
# 4   [741 Monroe Ave (Rutgers St), Rochester, NY 14...
# 5   [1325 Elmwood Ave (Lilac Dr.), Rochester, NY 1...
# 6   [80 Ridgeland Road, Rochester, NY 14623, Unite...
# 7   [1750 East Ave, Rochester, NY 14610, United St...
# 8   [230 Monroe Ave, Rochester, NY 14607, United S...
# 9   [125 White Spruce Blvd, Rochester, NY 14623, U...
# 10  [17 Richmond St, Rochester, NY 14607, United S...
# 11  [38 Saint Paul St, Rochester, NY 14604, United...
# 12  [120 Mushroom Blvd, Rochester, NY 14623, Unite...
# 13  [490 State St, Rochester, NY 14608, United Sta...
# 14  [302 Goodman St N (at Village Gate Square), Ro...
# 15  [2805 W Henrietta Rd, Rochester, NY 14623, Uni...
# 16  [5 Public Market (South Union Street), Rochest...
# 17  [360 Thurston Rd, Rochester, NY 14619, United ...
# 18               [Rochester, NY 14620, United States]
# 19  [1015 Clinton Ave S, Rochester, NY 14620, Unit...
# 20  [1776 Dewey Ave, Rochester, NY 14615, United S...
# 21  [742 South Ave, Rochester, NY 14620, United St...
# 22  [916 Panorama Trl S, Rochester, NY 14625, Unit...
# 23                          [New York, United States]
# 24  [21 Shepard St, Rochester, NY 14620, United St...
# 25  [998 Clinton Ave S, Rochester, NY 14620, Unite...
# 26  [658 Park Ave (Berkeley St), Rochester, NY 146...
# 27  [1415 N Clinton Ave, Rochester, NY 14621, Unit...
# 28  [746 Monroe Ave, Rochester, NY 14607, United S...
# 29  [740 E Ridge Rd, Rochester, NY 14621, United S...
# 30  [1485 Dewey Ave, Rochester, NY 14615, United S...
# 31  [746 Monroe Ave (Rutgers St), Rochester, NY 14...
# 32  [4835 W Henrietta Rd, Henrietta, NY 14467, Uni...
# 33  [555 E Ridge Rd, Rochester, NY 14621, United S...
# 34  [90 Henrietta St (Monroe Ave), Rochester, NY 1...
# 35  [503 South Ave, Rochester, NY 14620, United St...
# 36  [410 White Spruce Blvd, Rochester, NY 14623, U...
# 37  [1384 Norton St, Rochester, NY 14621, United S...
# 38  [1360 Dewey Ave, Rochester, NY 14613, United S...
# 39  [777 Plymouth Ave (Violetta St), Rochester, NY...
# 40  [777 S Plymouth Ave, Rochester, NY 14608, Unit...
# 41               [Rochester, NY 14607, United States]
# 42  [1675 Mount Hope Ave, Rochester, NY 14620, Uni...
# 43  [1220 Fairport Rd, Fairport, NY 14450, United ...
# 44  [1780 E Ridge Rd, Rochester, NY 14622, United ...
# 45  [1843 Empire Blvd (btwn Bay & Smith Rd), Webst...
# 46  [2235 Buffalo Rd, Rochester, NY 14624, United ...
# 47  [262 Park Ave, Rochester, NY 14607, United Sta...
# 48  [2317 Buffalo Rd, Rochester, NY 14624, United ...
# 49  [690 Park Ave, Rochester, NY 14607, United Sta...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.12057077237436...  43.120571 -77.593295
# 1   [{'label': 'display', 'lat': 43.13836669921875...  43.138367 -77.595306
# 2   [{'label': 'display', 'lat': 43.14223, 'lng': ...  43.142230 -77.576660
# 3   [{'label': 'display', 'lat': 43.14182964095191...  43.141830 -77.608803
# 4   [{'label': 'display', 'lat': 43.14328031660690...  43.143280 -77.588074
# 5   [{'label': 'display', 'lat': 43.12335968017578...  43.123360 -77.603455
# 6   [{'label': 'display', 'lat': 43.09191099999999...  43.091911 -77.600555
# 7   [{'label': 'display', 'lat': 43.14593922729457...  43.145939 -77.556650
# 8   [{'label': 'display', 'lat': 43.15001250635744...  43.150013 -77.599471
# 9   [{'label': 'display', 'lat': 43.10541676249526...  43.105417 -77.617868
# 10  [{'label': 'display', 'lat': 43.158662, 'lng':...  43.158662 -77.597982
# 11  [{'label': 'display', 'lat': 43.15747833251953...  43.157478 -77.609131
# 12  [{'label': 'display', 'lat': 43.09114583751294...  43.091146 -77.619013
# 13  [{'label': 'display', 'lat': 43.1638, 'lng': -...  43.163800 -77.621828
# 14  [{'label': 'display', 'lat': 43.15900023987086...  43.159000 -77.584915
# 15  [{'label': 'display', 'lat': 43.09567802702606...  43.095678 -77.632644
# 16  [{'label': 'display', 'lat': 43.16582198528039...  43.165822 -77.590049
# 17  [{'label': 'display', 'lat': 43.137796, 'lng':...  43.137796 -77.650707
# 18  [{'label': 'display', 'lat': 43.123978, 'lng':...  43.123978 -77.617600
# 19  [{'label': 'display', 'lat': 43.13855378592741...  43.138554 -77.595241
# 20  [{'label': 'display', 'lat': 43.19997668709689...  43.199977 -77.638540
# 21  [{'label': 'display', 'lat': 43.14071099999999...  43.140711 -77.604664
# 22  [{'label': 'display', 'lat': 43.12601755030661...  43.126018 -77.490869
# 23  [{'label': 'display', 'lat': 43.10173225582329...  43.101732 -77.609120
# 24  [{'label': 'display', 'lat': 43.14012899999999...  43.140129 -77.583647
# 25  [{'label': 'display', 'lat': 43.13888223273507...  43.138882 -77.595131
# 26  [{'label': 'display', 'lat': 43.1482724, 'lng'...  43.148272 -77.577978
# 27  [{'label': 'display', 'lat': 43.185668, 'lng':...  43.185668 -77.615100
# 28  [{'label': 'display', 'lat': 43.14330862108667...  43.143309 -77.587998
# 29  [{'label': 'display', 'lat': 43.19701518549416...  43.197015 -77.599394
# 30  [{'label': 'display', 'lat': 43.1940479, 'lng'...  43.194048 -77.639175
# 31  [{'label': 'display', 'lat': 43.1435244741491,...  43.143524 -77.587816
# 32  [{'label': 'display', 'lat': 43.05699751101155...  43.056998 -77.654008
# 33  [{'label': 'display', 'lat': 43.19526099248838...  43.195261 -77.603523
# 34  [{'label': 'display', 'lat': 43.14060087993469...  43.140601 -77.593241
# 35  [{'label': 'display', 'lat': 43.14587783813476...  43.145878 -77.605705
# 36  [{'label': 'display', 'lat': 43.10295083333333...  43.102951 -77.618160
# 37  [{'label': 'display', 'lat': 43.187911, 'lng':...  43.187911 -77.585202
# 38  [{'label': 'entrance', 'lat': 43.191407, 'lng'...  43.191383 -77.638580
# 39  [{'label': 'display', 'lat': 43.14089217839027...  43.140892 -77.621461
# 40  [{'label': 'display', 'lat': 43.1409612, 'lng'...  43.140961 -77.621404
# 41  [{'label': 'display', 'lat': 43.149205, 'lng':...  43.149205 -77.589111
# 42  [{'label': 'display', 'lat': 43.11731403610523...  43.117314 -77.621407
# 43  [{'label': 'display', 'lat': 43.102745, 'lng':...  43.102745 -77.465935
# 44  [{'label': 'display', 'lat': 43.20172882080078...  43.201729 -77.570084
# 45  [{'label': 'display', 'lat': 43.18850206072805...  43.188502 -77.505374
# 46  [{'label': 'display', 'lat': 43.14679736695471...  43.146797 -77.710589
# 47  [{'label': 'display', 'lat': 43.15050888061523...  43.150509 -77.588768
# 48  [{'label': 'display', 'lat': 43.14513397216797...  43.145134 -77.711411
# 49  [{'label': 'display', 'lat': 43.147961, 'lng':...  43.147961 -77.577236
#
#    postalCode     state                        id
# 0       14618        NY  4babc69ff964a52098c83ae3
# 1       14620        NY  4bd77c760b779c74a75605a0
# 2       14620        NY  501d4fb2e4b0cf97af8c62ef
# 3       14620        NY  5bb7cd73a35f460025d0173f
# 4       14607        NY  4bdf4a66e75c0f472897ca03
# 5       14620        NY  554f6797498ece2b655eb427
# 6       14623        NY  53ebd1fd498e6ee1435862dc
# 7       14610        NY  518e68d7498ef0d390d3128b
# 8       14607        NY  4c0581a7191f20a1f22fe314
# 9       14623        NY  4b85bed7f964a520997031e3
# 10      14607        NY  4e4e47e4bd4101d0d7a6bb5e
# 11      14604        NY  504140e8e4b00fd08e8d0511
# 12      14623        NY  4b9962e9f964a520967735e3
# 13      14608        NY  4aafc2cdf964a520a46420e3
# 14      14607        NY  4b61ae35f964a520f41c2ae3
# 15      14623        NY  4b6c99d0f964a520c0452ce3
# 16      14609        NY  559c0b82498ed13231e6bea8
# 17      14619        NY  4d3ba5e2557d6dcb63f53244
# 18      14620        NY  5ba6920c898bdc002b147887
# 19      14620        NY  51f3094b498e3da43eb93dc2
# 20      14615        NY  4b643be6f964a52089a52ae3
# 21      14620        NY  4f32622e19836c91c7d2744b
# 22      14625        NY  4b8c4fc3f964a520efc932e3
# 23        NaN  New York  4e8473d9b8f7a99150a0d208
# 24      14620        NY  4f321ee219836c91c7b80371
# 25      14620        NY  4b4a8dc2f964a5207f8a26e3
# 26      14607        NY  4ace2e17f964a520dfce20e3
# 27      14621        NY  4e3f010de4cdab9b93587099
# 28      14607        NY  581504ccd67c3973889bf23f
# 29      14621        NY  4bc31e264cdfc9b699dc9621
# 30      14615        NY  5776b41a498e9b4c2d48fb3d
# 31      14607        NY  583e323e9b615c0be1466522
# 32      14467        NY  4bdd9738aebd2d7f6663af51
# 33      14621        NY  4be930afd837c9b67a1ba606
# 34      14620        NY  4bb4cfefa70595216fb91bce
# 35      14620        NY  4f32b3d319836c91c7f15ce9
# 36      14623        NY  4c5db9ae857ca5938dbbcdcb
# 37      14621        NY  4c66e1328e9120a1482dd964
# 38      14613        NY  4ce7613ff1c6236a917859f0
# 39      14608        NY  5b129d67974617002c0447f2
# 40      14608        NY  5ccd3303446ea6002c46eef4
# 41      14607        NY  50746a68e4b0531e5c6324a7
# 42      14620        NY  521bd78e498e0a529505bdc8
# 43      14450        NY  58b9cec00aac755b158af2f5
# 44      14622        NY  5004c270e4b0004dbf991fb9
# 45      14580        NY  4b47dfdff964a5206a4226e3
# 46      14624        NY  4ba16b08f964a52036b537e3
# 47      14607        NY  4f32561319836c91c7cdb750
# 48      14624        NY  4f44a68719836ed001958e62
# 49      14607        NY  4e4c846cbd413c4cc669f747

# %%
dataframe_filtered.name
# Out:
# 0                  Golden Dynasty Chinese Restaurant
# 1                   Lilu Cafe & Ethiopian Restaurant
# 2               The Restaurant At The Armory (TRATA)
# 3          Peppapot Jamaican Restaurant and Catering
# 4                                     SEA Restaurant
# 5                                Joey B's Restaurant
# 6                                   Restaurant Depot
# 7     Amore Italian Restaurant & Wine Bar by Wegmans
# 8                                 Dac Hoa Restaurant
# 9                      Chopsticks Chinese Restaurant
# 10                     Rong Cheng Chinese Restaurant
# 11                      LJ's Take Out & Restaurant 2
# 12                          Youngs Korean Restaurant
# 13                         Spiro's Family Restaurant
# 14                       Salena's Mexican Restaurant
# 15                            Seoul House Restaurant
# 16                               Restaurant Fiorella
# 17                        LJ's Take Out & Restaurant
# 18                                Akwaaba Restaurant
# 19                       Zemeta Ethiopian Restaurant
# 20                             Peppermill Restaurant
# 21                    Skippy's Vegeterian Restaurant
# 22                Timothy Patrick's Irish Restaurant
# 23                            Reflections Restaurant
# 24                           Savory Thyme Restaurant
# 25                            India House Restaurant
# 26                                  Jines Restaurant
# 27                           Wang Chinese Restaurant
# 28                         Cedar Lebanese Restaurant
# 29                                  Tom's Restaurant
# 30                Reggae Jamaica Restaurant & Bakery
# 31                                  Cedar Restaurant
# 32                                 Lehigh Restaurant
# 33                          Uncle Danny's Restaurant
# 34                               Rooney's Restaurant
# 35                                 Dashen Restaurant
# 36                 Kessler Restaurant Support Center
# 37                      King Food Chinese Restaurant
# 38                           Cactus Restaurant & Bar
# 39                  Kamara's West African Restaurant
# 40                       Kamara’s African Restaurant
# 41                              Alley Cat Restaurant
# 42                                    SEA Restaurant
# 43                  Dalia’s Mediterranean Restaurant
# 44                             Asian Jade Restaurant
# 45                              Charlie's Restaurant
# 46                               Pixley's Restaurant
# 47                                 Sapore Restaurant
# 48                   Number One Rochester Restaurant
# 49                         Kobay Japanese Restaurant
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ce7965ff5846> in <module>
# ----> 1 venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel
#       2
#       3 # add a red circle marker to represent the Conrad Hotel
#       4 folium.features.CircleMarker(
#       5     [latitude, longitude],
#
# NameError: name 'folium' is not defined

# %% [markdown]
# ### As is shown on the map, we should pick up the most popular location around the

# %% [markdown]
# ### Monroe Avenue -------- Yellow point on the map

# %%
address = 'Monroe Avenue, Rochester, NY'
#'102 North End Ave, New York, NY'#
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.1471568 -77.5947806

# %%
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='yellow',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'yellow',
    fill_opacity = 0.6
).add_to(venues_map)
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-effdc5c88226> in <module>
# ----> 1 folium.features.CircleMarker(
#       2     [latitude, longitude],
#       3     radius=10,
#       4     color='yellow',
#       5     popup='Conrad Hotel',
#
# NameError: name 'folium' is not defined
